# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Testing .html pLink output parsing

# %%
from loadfiles import *

# %%
infile = 'KM66/2.report/sample1/IdProTable_combine.html'
df_details, df_sum = load_plink_html(infile)

# %%
df_details
# Out:
#           Calc_M    Delta_M   Engine MatchedIons MissCleaveNum  \
# 0    2666.371244  -0.005930  1.pFind           0            -1
# 1    2666.371244  -0.005830  1.pFind           0            -1
# 2    2666.371244   0.002270  1.pFind           0            -1
# 3    2666.371244   0.004420  1.pFind           0            -1
# 4    2666.371244   0.000170  1.pFind           0            -1
# 5    2822.472354   0.000390  1.pFind           0            -1
# 6    2024.981184   0.004830  1.pFind           0            -1
# 7    2666.371244  -0.001220  1.pFind           0            -1
# 8    2666.371244   0.000470  1.pFind           0            -1
# 9    2181.082294  -0.001880  1.pFind           0            -1
# 10   2528.386314  -0.001700  1.pFind           0            -1
# 11   2528.386314   0.002430  1.pFind           0            -1
# 12   2528.386314  -0.001050  1.pFind           0            -1
# 13   2188.200414   0.002050  1.pFind           0            -1
# 14   2528.386314   0.002000  1.pFind           0            -1
# 15   2344.301524   0.996240  1.pFind           0            -1
# 16   2528.386314  -0.001470  1.pFind           0            -1
# 17   2561.392524  -0.001230  1.pFind           0            -1
# 18   2433.297564  -0.002230  1.pFind           0            -1
# 19   2561.392524   0.002040  1.pFind           0            -1
# 20   2336.226334   0.001400  1.pFind           0            -1
# 21   2933.513404  -0.009520  1.pFind           0            -1
# 22   3741.990064  -0.008300  1.pFind           0            -1
# 23   3613.895104   0.007190  1.pFind           0            -1
# 24   2689.403484   0.000010  1.pFind           0            -1
# 25   2817.498444   0.001170  1.pFind           0            -1
# 26   2689.403484  -0.005970  1.pFind           0            -1
# 27   2817.498444   0.005040  1.pFind           0            -1
# 28   2817.498444   0.002290  1.pFind           0            -1
# 29   2955.614134  -0.001420  1.pFind           0            -1
# ..           ...        ...      ...         ...           ...
# 249  1807.931574   0.004040  1.pFind           0            -1
# 250  2896.648454   1.019960  1.pFind           0            -1
# 251  4871.482814   0.007150  1.pFind           0            -1
# 252  1991.105124  -0.000430  1.pFind           0            -1
# 253  2311.165554   0.001860  1.pFind           0            -1
# 254  1778.927504  -0.001650  1.pFind           0            -1
# 255  2254.159354   0.016380  1.pFind           0            -1
# 256  1989.005484   0.002290  1.pFind           0            -1
# 257  2068.189164  -0.003670  1.pFind           0            -1
# 258  2096.195314  -0.000060  1.pFind           0            -1
# 259  2281.238974   0.002740  1.pFind           0            -1
# 260  2025.133054   0.001160  1.pFind           0            -1
# 261  2025.133054   0.001040  1.pFind           0            -1
# 262  2025.133054   0.998000  1.pFind           0            -1
# 263  2187.211034   0.000100  1.pFind           0            -1
# 264  3601.836244   0.005970  1.pFind           0            -1
# 265  4061.094294   0.000270  1.pFind           0            -1
# 266  4061.094294  -0.001840  1.pFind           0            -1
# 267  4018.099714  -0.009550  1.pFind           0            -1
# 268  4018.099714   0.005700  1.pFind           0            -1
# 269  4018.099714   1.009340  1.pFind           0            -1
# 270  3668.903574  -0.003760  1.pFind           0            -1
# 271  3581.831154  -0.010660  1.pFind           0            -1
# 272  3581.831154   0.007160  1.pFind           0            -1
# 273  3581.831154   0.025220  1.pFind           0            -1
# 274  3581.831154   0.993500  1.pFind           0            -1
# 275  3524.824954   0.008220  1.pFind           0            -1
# 276  3281.703044   0.003930  1.pFind           0            -1
# 277  4190.080224   0.007350  1.pFind           0            -1
# 278  3279.683374   0.000640  1.pFind           0            -1
#
#                                          Modification Order  \
# 0     9,E(Carbamidomethyl_C);11,L(Carbamidomethyl_C);     1
# 1     9,E(Carbamidomethyl_C);11,L(Carbamidomethyl_C);     2
# 2     9,E(Carbamidomethyl_C);11,L(Carbamidomethyl_C);     3
# 3     9,E(Carbamidomethyl_C);11,L(Carbamidomethyl_C);     4
# 4     9,E(Carbamidomethyl_C);11,L(Carbamidomethyl_C);     5
# 5     9,E(Carbamidomethyl_C);11,L(Carbamidomethyl_C);     6
# 6      3,E(Carbamidomethyl_C);5,L(Carbamidomethyl_C);     7
# 7     9,E(Carbamidomethyl_C);11,L(Carbamidomethyl_C);     8
# 8     9,E(Carbamidomethyl_C);11,L(Carbamidomethyl_C);     9
# 9      3,E(Carbamidomethyl_C);5,L(Carbamidomethyl_C);    10
# 10                                               null     1
# 11                                               null     2
# 12                                               null     3
# 13                                               null     4
# 14                                               null     5
# 15                                               null     6
# 16                                               null     7
# 17                                               null     1
# 18                                               null     2
# 19                                               null     3
# 20                                               null     1
# 21                                               null     2
# 22                                               null     1
# 23                                               null     2
# 24                                               null     1
# 25                                               null     2
# 26                                               null     3
# 27                                               null     4
# 28                                               null     5
# 29                                               null     1
# ..                                                ...   ...
# 249                                              null     1
# 250                                              null     1
# 251                                              null     1
# 252                                              null     1
# 253                                              null     1
# 254                                              null     1
# 255                                              null     1
# 256                                              null     1
# 257                                              null     1
# 258                                              null     1
# 259                                              null     1
# 260                                              null     1
# 261                                              null     2
# 262                                              null     3
# 263                                              null     1
# 264                                              null     1
# 265                                              null     1
# 266                                              null     2
# 267                                              null     1
# 268                                              null     2
# 269                                              null     3
# 270                                              null     1
# 271                                              null     1
# 272                                              null     2
# 273                                              null     3
# 274                                              null     4
# 275                                              null     1
# 276                                              null     1
# 277  32,V(Carbamidomethyl_C);34,D(Carbamidomethyl_C);     1
# 278                                              null     1
#
#                  Proteins Rank   Sample      Score  \
# 0       RpoC(74)-RpoC(79)    1  1.pFind  4.46e-002
# 1       RpoC(74)-RpoC(79)    1  1.pFind  4.69e-002
# 2       RpoC(74)-RpoC(79)    1  1.pFind  7.04e-002
# 3       RpoC(74)-RpoC(79)    1  1.pFind  9.44e-002
# 4       RpoC(74)-RpoC(79)    1  1.pFind  1.27e-001
# 5       RpoC(74)-RpoC(79)    1  1.pFind  1.54e-001
# 6       RpoC(74)-RpoC(79)    1  1.pFind  1.63e-001
# 7       RpoC(74)-RpoC(79)    1  1.pFind  1.71e-001
# 8       RpoC(74)-RpoC(79)    1  1.pFind  2.47e-001
# 9       RpoC(74)-RpoC(79)    1  1.pFind  8.92e-001
# 10    UvrD(623)-UvrD(486)    1  1.pFind  7.02e-007
# 11    UvrD(623)-UvrD(486)    1  1.pFind  1.42e-006
# 12    UvrD(623)-UvrD(486)    1  1.pFind  1.66e-006
# 13    UvrD(623)-UvrD(486)    1  1.pFind  4.94e-006
# 14    UvrD(623)-UvrD(486)    1  1.pFind  8.68e-006
# 15    UvrD(623)-UvrD(486)    1  1.pFind  1.29e-005
# 16    UvrD(623)-UvrD(486)    1  1.pFind  6.36e-004
# 17    RpoC(789)-RpoC(334)    1  1.pFind  8.12e-003
# 18    RpoC(789)-RpoC(334)    1  1.pFind  1.68e-002
# 19    RpoC(789)-RpoC(334)    1  1.pFind  5.54e-002
# 20    RpoB(161)-RpoC(781)    1  1.pFind  2.34e-007
# 21    RpoB(161)-RpoC(781)    1  1.pFind  1.04e-005
# 22   RpoC(789)-RpoC(1132)    1  1.pFind  1.76e-011
# 23   RpoC(789)-RpoC(1132)    1  1.pFind  4.56e-010
# 24    RpoC(789)-RpoB(163)    1  1.pFind  4.59e-007
# 25    RpoC(789)-RpoB(163)    1  1.pFind  2.20e-005
# 26    RpoC(789)-RpoB(163)    1  1.pFind  6.76e-005
# 27    RpoC(789)-RpoB(163)    1  1.pFind  1.76e-003
# 28    RpoC(789)-RpoB(163)    1  1.pFind  5.32e-003
# 29   RpoC(789)-RpoB(1073)    1  1.pFind  4.81e-003
# ..                    ...  ...      ...        ...
# 249    RpoB(914)-RpoB(13)    1  1.pFind  2.29e-002
# 250   RpoA(298)-RpoA(304)    1  1.pFind  2.70e-002
# 251  RpoB(844)-RpoB(1262)    1  1.pFind  1.84e-005
# 252   RpoB(639)-RpoB(431)    1  1.pFind  5.70e-012
# 253   RpoB(639)-RpoB(914)    1  1.pFind  8.04e-004
# 254   RpoB(639)-RpoC(334)    1  1.pFind  1.24e-003
# 255    RpoB(639)-RpoC(40)    1  1.pFind  1.93e-005
# 256   RpoB(639)-RpoC(992)    1  1.pFind  2.22e-002
# 257  RpoB(719)-RpoB(1028)    1  1.pFind  6.44e-004
# 258  RpoB(719)-RpoB(1032)    1  1.pFind  1.57e-004
# 259   RpoB(719)-RpoB(163)    1  1.pFind  7.73e-002
# 260   RpoB(719)-RpoC(334)    1  1.pFind  1.53e-008
# 261   RpoB(719)-RpoC(334)    1  1.pFind  1.75e-007
# 262   RpoB(719)-RpoC(334)    1  1.pFind  4.29e-002
# 263   RpoB(914)-RpoC(395)    1  1.pFind  7.42e-003
# 264   RpoB(844)-RpoB(639)    1  1.pFind  2.67e-009
# 265   RpoB(844)-RpoB(890)    1  1.pFind  1.67e-005
# 266   RpoB(844)-RpoB(890)    1  1.pFind  3.60e-005
# 267   RpoB(844)-RpoB(900)    1  1.pFind  2.58e-004
# 268   RpoB(844)-RpoB(900)    1  1.pFind  5.05e-004
# 269   RpoB(844)-RpoB(900)    1  1.pFind  1.52e-001
# 270   RpoB(844)-RpoB(909)    1  1.pFind  1.90e-002
# 271   RpoB(844)-RpoB(914)    1  1.pFind  4.51e-006
# 272   RpoB(844)-RpoB(914)    1  1.pFind  2.10e-005
# 273   RpoB(844)-RpoB(914)    1  1.pFind  7.10e-005
# 274   RpoB(844)-RpoB(914)    1  1.pFind  8.16e-005
# 275    RpoB(844)-RpoC(40)    1  1.pFind  1.51e-008
# 276    RpoB(844)-RpoC(50)    1  1.pFind  2.88e-002
# 277    RpoB(844)-RpoC(66)    1  1.pFind  3.75e-011
# 278   RpoB(844)-UvrD(501)    1  1.pFind  2.17e-004
#
#                                               Sequence  \
# 0                       IFGPVKDYECLCGKYK(14)-LKHR(2):0
# 1                       IFGPVKDYECLCGKYK(14)-LKHR(2):0
# 2                       IFGPVKDYECLCGKYK(14)-LKHR(2):0
# 3                       IFGPVKDYECLCGKYK(14)-LKHR(2):0
# 4                       IFGPVKDYECLCGKYK(14)-LKHR(2):0
# 5                      IFGPVKDYECLCGKYK(14)-RLKHR(3):0
# 6                              DYECLCGKYK(8)-LKHR(2):0
# 7                       IFGPVKDYECLCGKYK(14)-LKHR(2):0
# 8                       IFGPVKDYECLCGKYK(14)-LKHR(2):0
# 9                             DYECLCGKYK(8)-RLKHR(3):0
# 10                       LYGKEVYHRPSR(4)-VIKDSGLR(3):0
# 11                       LYGKEVYHRPSR(4)-VIKDSGLR(3):0
# 12                       LYGKEVYHRPSR(4)-VIKDSGLR(3):0
# 13                          LYGKEVYHR(4)-VIKDSGLR(3):0
# 14                       LYGKEVYHRPSR(4)-VIKDSGLR(3):0
# 15                         RLYGKEVYHR(5)-VIKDSGLR(3):0
# 16                       LYGKEVYHRPSR(4)-VIKDSGLR(3):0
# 17                    KGLADTALKTANSGYLTR(9)-GKQGR(2):0
# 18                     GLADTALKTANSGYLTR(8)-GKQGR(2):0
# 19                    KGLADTALKTANSGYLTR(9)-GKQGR(2):0
# 20                     SPGVFFDSDKGK(10)-KGLADTALK(1):0
# 21               SPGVFFDSDKGKTHSSGK(10)-KGLADTALK(1):0
# 22        KGLADTALKTANSGYLTR(9)-IPQESGGTKDITGGLPR(9):0
# 23         GLADTALKTANSGYLTR(8)-IPQESGGTKDITGGLPR(9):0
# 24                  GLADTALKTANSGYLTR(8)-GKTHSSGK(2):0
# 25                 KGLADTALKTANSGYLTR(9)-GKTHSSGK(2):0
# 26                  GLADTALKTANSGYLTR(8)-GKTHSSGK(2):0
# 27                 KGLADTALKTANSGYLTR(9)-GKTHSSGK(2):0
# 28                 KGLADTALKTANSGYLTR(9)-GKTHSSGK(2):0
# 29                KGLADTALKTANSGYLTR(9)-HGNKGVISK(4):0
# ..                                                 ...
# 249                           ASDVKDSSLR(5)-KDFGK(1):0
# 250                 TPNLGKKSLTEIK(7)-SLTEIKDVLASR(6):0
# 251  DTKLGPEEITADIPNVGEAALSK(3)-STGSYSLVTQQPLGGKAQF...
# 252                          SKGESSLFSR(2)-KLIDIR(1):0
# 253                      SKGESSLFSR(2)-ASDVKDSSLR(5):0
# 254                           SKGESSLFSR(2)-GKQGR(2):0
# 255                        SKGESSLFSR(2)-KPETINYR(1):0
# 256                          SKGESSLFSR(2)-TKESYK(2):0
# 257                      AVAVDSGVTAVAKR(13)-KLEAK(1):0
# 258                      AVAVDSGVTAVAKR(13)-LEAKR(4):0
# 259                   AVAVDSGVTAVAKR(13)-GKTHSSGK(2):0
# 260                      AVAVDSGVTAVAKR(13)-GKQGR(2):0
# 261                      AVAVDSGVTAVAKR(13)-GKQGR(2):0
# 262                      AVAVDSGVTAVAKR(13)-GKQGR(2):0
# 263                      ASDVKDSSLR(5)-GLATTIKAAK(7):0
# 264         DTKLGPEEITADIPNVGEAALSK(3)-SKGESSLFSR(2):0
# 265     DTKLGPEEITADIPNVGEAALSK(3)-VTPKGETQLTPEEK(4):0
# 266     DTKLGPEEITADIPNVGEAALSK(3)-VTPKGETQLTPEEK(4):0
# 267     DTKLGPEEITADIPNVGEAALSK(3)-GETQLTPEEKLLR(10):0
# 268     DTKLGPEEITADIPNVGEAALSK(3)-GETQLTPEEKLLR(10):0
# 269     DTKLGPEEITADIPNVGEAALSK(3)-GETQLTPEEKLLR(10):0
# 270        DTKLGPEEITADIPNVGEAALSK(3)-AIFGEKASDVK(6):0
# 271         DTKLGPEEITADIPNVGEAALSK(3)-ASDVKDSSLR(5):0
# 272         DTKLGPEEITADIPNVGEAALSK(3)-ASDVKDSSLR(5):0
# 273         DTKLGPEEITADIPNVGEAALSK(3)-ASDVKDSSLR(5):0
# 274         DTKLGPEEITADIPNVGEAALSK(3)-ASDVKDSSLR(5):0
# 275           DTKLGPEEITADIPNVGEAALSK(3)-KPETINYR(1):0
# 276             DTKLGPEEITADIPNVGEAALSK(3)-TFKPER(3):0
# 277     DTKLGPEEITADIPNVGEAALSK(3)-IFGPVKDYECLCGK(6):0
# 278            DTKLGPEEITADIPNVGEAALSK(3)-GEKGQTR(3):0
#
#                                    Spectrum         ppm prot1  res1 prot2  \
# 0    File2666 Spectrum1002 scans: 11893.dta   -2.223161  RpoC    74  RpoC
# 1    File2666 Spectrum1034 scans: 12008.dta   -2.185671  RpoC    74  RpoC
# 2    File2666 Spectrum1069 scans: 12134.dta    0.851022  RpoC    74  RpoC
# 3    File2666 Spectrum1101 scans: 12259.dta    1.657055  RpoC    74  RpoC
# 4    File2666 Spectrum1035 scans: 12014.dta    0.063733  RpoC    74  RpoC
# 5     File2666 Spectrum981 scans: 11815.dta    0.138127  RpoC    74  RpoC
# 6      File2666 Spectrum403 scans: 9205.dta    2.384016  RpoC    74  RpoC
# 7    File2666 Spectrum1020 scans: 11940.dta   -0.457378  RpoC    74  RpoC
# 8    File2666 Spectrum1132 scans: 12379.dta    0.176203  RpoC    74  RpoC
# 9      File2666 Spectrum316 scans: 8665.dta   -0.861560  RpoC    74  RpoC
# 10     File2666 Spectrum539 scans: 9885.dta   -0.672098  UvrD   623  UvrD
# 11     File2666 Spectrum568 scans: 9992.dta    0.960704  UvrD   623  UvrD
# 12     File2666 Spectrum537 scans: 9875.dta   -0.415119  UvrD   623  UvrD
# 13    File2666 Spectrum746 scans: 10887.dta    0.936411  UvrD   623  UvrD
# 14    File2666 Spectrum572 scans: 10003.dta    0.790703  UvrD   623  UvrD
# 15     File2666 Spectrum547 scans: 9916.dta  424.599523  UvrD   623  UvrD
# 16    File2666 Spectrum606 scans: 10111.dta   -0.581167  UvrD   623  UvrD
# 17    File2666 Spectrum842 scans: 11317.dta   -0.480019  RpoC   789  RpoC
# 18   File2666 Spectrum1324 scans: 13147.dta   -0.916073  RpoC   789  RpoC
# 19    File2666 Spectrum848 scans: 11335.dta    0.796128  RpoC   789  RpoC
# 20   File2666 Spectrum1782 scans: 15023.dta    0.598998  RpoB   161  RpoC
# 21    File2666 Spectrum978 scans: 11810.dta   -3.244152  RpoB   161  RpoC
# 22   File2666 Spectrum1731 scans: 14834.dta   -2.217479  RpoC   789  RpoC
# 23   File2666 Spectrum2154 scans: 16369.dta    1.988985  RpoC   789  RpoC
# 24    File2666 Spectrum919 scans: 11628.dta    0.003717  RpoC   789  RpoB
# 25    File2666 Spectrum596 scans: 10084.dta    0.415113  RpoC   789  RpoB
# 26    File2666 Spectrum920 scans: 11631.dta   -2.218997  RpoC   789  RpoB
# 27    File2666 Spectrum583 scans: 10058.dta    1.788178  RpoC   789  RpoB
# 28    File2666 Spectrum601 scans: 10094.dta    0.812487  RpoC   789  RpoB
# 29    File2666 Spectrum909 scans: 11583.dta   -0.480278  RpoC   789  RpoB
# ..                                      ...         ...   ...   ...   ...
# 249    File2666 Spectrum569 scans: 9995.dta    2.233349  RpoB   914  RpoB
# 250  File2666 Spectrum2936 scans: 19486.dta  351.871030  RpoA   298  RpoA
# 251  File2666 Spectrum2981 scans: 19700.dta    1.467420  RpoB   844  RpoB
# 252  File2666 Spectrum1631 scans: 14441.dta   -0.215851  RpoB   639  RpoB
# 253  File2666 Spectrum1030 scans: 11998.dta    0.804437  RpoB   639  RpoB
# 254    File2666 Spectrum305 scans: 8617.dta   -0.927001  RpoB   639  RpoC
# 255   File2666 Spectrum971 scans: 11797.dta    7.263269  RpoB   639  RpoC
# 256    File2666 Spectrum551 scans: 9922.dta    1.150745  RpoB   639  RpoC
# 257   File2666 Spectrum733 scans: 10792.dta   -1.773639  RpoB   719  RpoB
# 258   File2666 Spectrum732 scans: 10786.dta   -0.028610  RpoB   719  RpoB
# 259    File2666 Spectrum211 scans: 8114.dta    1.200570  RpoB   719  RpoB
# 260    File2666 Spectrum437 scans: 9396.dta    0.572517  RpoB   719  RpoC
# 261    File2666 Spectrum462 scans: 9514.dta    0.513291  RpoB   719  RpoC
# 262    File2666 Spectrum491 scans: 9652.dta  492.319634  RpoB   719  RpoC
# 263   File2666 Spectrum929 scans: 11656.dta    0.045699  RpoB   914  RpoC
# 264  File2666 Spectrum2885 scans: 19263.dta    1.657022  RpoB   844  RpoB
# 265  File2666 Spectrum2581 scans: 18112.dta    0.066468  RpoB   844  RpoB
# 266  File2666 Spectrum2578 scans: 18103.dta   -0.452968  RpoB   844  RpoB
# 267  File2666 Spectrum3090 scans: 20184.dta   -2.376155  RpoB   844  RpoB
# 268  File2666 Spectrum3081 scans: 20148.dta    1.418223  RpoB   844  RpoB
# 269  File2666 Spectrum3151 scans: 20475.dta  251.072337  RpoB   844  RpoB
# 270  File2666 Spectrum2945 scans: 19525.dta   -1.024549  RpoB   844  RpoB
# 271  File2666 Spectrum2697 scans: 18617.dta   -2.975303  RpoB   844  RpoB
# 272  File2666 Spectrum2686 scans: 18552.dta    1.998412  RpoB   844  RpoB
# 273  File2666 Spectrum2759 scans: 18862.dta    7.039062  RpoB   844  RpoB
# 274  File2666 Spectrum2780 scans: 18924.dta  277.217241  RpoB   844  RpoB
# 275  File2666 Spectrum2555 scans: 18036.dta    2.331359  RpoB   844  RpoC
# 276  File2666 Spectrum2592 scans: 18159.dta    1.197180  RpoB   844  RpoC
# 277  File2666 Spectrum3154 scans: 20490.dta    1.753718  RpoB   844  RpoC
# 278  File2666 Spectrum2379 scans: 17372.dta    0.195081  RpoB   844  UvrD
#
#      res2
# 0      79
# 1      79
# 2      79
# 3      79
# 4      79
# 5      79
# 6      79
# 7      79
# 8      79
# 9      79
# 10    486
# 11    486
# 12    486
# 13    486
# 14    486
# 15    486
# 16    486
# 17    334
# 18    334
# 19    334
# 20    781
# 21    781
# 22   1132
# 23   1132
# 24    163
# 25    163
# 26    163
# 27    163
# 28    163
# 29   1073
# ..    ...
# 249    13
# 250   304
# 251  1262
# 252   431
# 253   914
# 254   334
# 255    40
# 256   992
# 257  1028
# 258  1032
# 259   163
# 260   334
# 261   334
# 262   334
# 263   395
# 264   639
# 265   890
# 266   890
# 267   900
# 268   900
# 269   900
# 270   909
# 271   914
# 272   914
# 273   914
# 274   914
# 275    40
# 276    50
# 277    66
# 278   501
#
# [277 rows x 18 columns]

# %%
df_sum
# Out:
#     Coverage(%) Description MW ModifiedSpecNum Non-ModifiedSpecNum Order  \
# 0             0        null  0              10                   0     1
# 1             0        null  0               0                   7     2
# 2             0        null  0               0                   3     3
# 3             0        null  0               0                   2     4
# 4             0        null  0               0                   2     5
# 5             0        null  0               0                   5     6
# 6             0        null  0               0                   2     7
# 7             0        null  0               9                   0     8
# 8             0        null  0               0                   2     9
# 9             0        null  0               0                  38    10
# 10            0        null  0               0                   1    11
# 11            0        null  0               0                   1    12
# 12            0        null  0               0                   1    13
# 13            0        null  0               0                   1    14
# 14            0        null  0               0                   1    15
# 15            0        null  0               0                   1    16
# 16            0        null  0               0                   1    17
# 17            0        null  0               0                   1    18
# 18            0        null  0               0                   1    19
# 19            0        null  0               0                   1    20
# 20            0        null  0               0                   1    21
# 21            0        null  0               0                   1    22
# 22            0        null  0               0                   1    23
# 23            0        null  0               0                   1    24
# 24            0        null  0               0                   1    25
# 25            0        null  0               0                   1    26
# 26            0        null  0               0                   1    27
# 27            0        null  0               0                   1    28
# 28            0        null  0               0                   1    29
# 29            0        null  0               0                   1    30
# ..          ...         ... ..             ...                 ...   ...
# 134           0        null  0               0                   2   135
# 135           0        null  0               0                   1   136
# 136           0        null  0               0                   1   137
# 137           0        null  0               0                   1   138
# 138           0        null  0               1                   0   139
# 139           0        null  0               0                   1   140
# 140           0        null  0               0                   1   141
# 141           0        null  0               0                   1   142
# 142           0        null  0               0                   1   143
# 143           0        null  0               0                   1   144
# 144           0        null  0               0                   1   145
# 145           0        null  0               0                   1   146
# 146           0        null  0               0                   1   147
# 147           0        null  0               0                   1   148
# 148           0        null  0               0                   1   149
# 149           0        null  0               0                   1   150
# 150           0        null  0               0                   1   151
# 151           0        null  0               0                   1   152
# 152           0        null  0               0                   1   153
# 153           0        null  0               0                   3   154
# 154           0        null  0               0                   1   155
# 155           0        null  0               0                   1   156
# 156           0        null  0               0                   2   157
# 157           0        null  0               0                   3   158
# 158           0        null  0               0                   1   159
# 159           0        null  0               0                   4   160
# 160           0        null  0               0                   1   161
# 161           0        null  0               0                   1   162
# 162           0        null  0               1                   0   163
# 163           0        null  0               0                   1   164
#
#                  ProteinAC SpecNum UniqueModifiedPepNum UniquePepNum pI prot1  \
# 0        RpoC(74)-RpoC(79)      10                    4            4  0  RpoC
# 1      UvrD(623)-UvrD(486)       7                    0            3  0  UvrD
# 2      RpoC(789)-RpoC(334)       3                    0            2  0  RpoC
# 3      RpoB(161)-RpoC(781)       2                    0            2  0  RpoB
# 4     RpoC(789)-RpoC(1132)       2                    0            2  0  RpoC
# 5      RpoC(789)-RpoB(163)       5                    0            2  0  RpoC
# 6     RpoC(789)-RpoB(1073)       2                    0            2  0  RpoC
# 7        RpoC(87)-RpoC(50)       9                    2            2  0  RpoC
# 8     RpoC(1132)-RpoC(996)       2                    0            2  0  RpoC
# 9      RpoB(260)-RpoB(279)      38                    0            2  0  RpoB
# 10     RpoC(1340)-RpoC(40)       1                    0            1  0  RpoC
# 11   RpoC(1340)-RpoC(1348)       1                    0            1  0  RpoC
# 12    RpoC(1340)-RpoC(219)       1                    0            1  0  RpoC
# 13    RpoC(1340)-RpoC(334)       1                    0            1  0  RpoC
# 14    RpoC(1340)-RpoC(345)       1                    0            1  0  RpoC
# 15     RpoC(1297)-RpoC(79)       1                    0            1  0  RpoC
# 16    RpoC(1348)-RpoB(914)       1                    0            1  0  RpoC
# 17     RpoC(1348)-RpoB(99)       1                    0            1  0  RpoC
# 18    RpoC(1348)-RpoC(219)       1                    0            1  0  RpoC
# 19    RpoC(1348)-RpoC(334)       1                    0            1  0  RpoC
# 20    RpoC(1348)-RpoC(345)       1                    0            1  0  RpoC
# 21      RpoC(1348)-RpoC(9)       1                    0            1  0  RpoC
# 22     RpoC(321)-RpoB(639)       1                    0            1  0  RpoC
# 23    RpoC(321)-RpoC(1340)       1                    0            1  0  RpoC
# 24    RpoC(321)-RpoC(1348)       1                    0            1  0  RpoC
# 25   RpoC(1151)-RpoC(1132)       1                    0            1  0  RpoC
# 26      RpoB(914)-RpoC(50)       1                    0            1  0  RpoB
# 27      RpoB(914)-RpoC(79)       1                    0            1  0  RpoB
# 28     RpoB(988)-RpoB(279)       1                    0            1  0  RpoB
# 29    RpoC(1072)-RpoB(265)       1                    0            1  0  RpoC
# ..                     ...     ...                  ...          ... ..   ...
# 134    RpoB(890)-RpoB(909)       2                    0            1  0  RpoB
# 135      RpoB(900)-RpoC(6)       1                    0            1  0  RpoB
# 136     RpoB(900)-RpoC(79)       1                    0            1  0  RpoB
# 137      RpoB(900)-RpoC(9)       1                    0            1  0  RpoB
# 138     RpoB(900)-RpoC(96)       1                    1            1  0  RpoB
# 139    RpoB(900)-UvrD(501)       1                    0            1  0  RpoB
# 140     RpoB(909)-RpoC(40)       1                    0            1  0  RpoB
# 141     RpoB(909)-RpoC(50)       1                    0            1  0  RpoB
# 142     RpoB(914)-RpoB(13)       1                    0            1  0  RpoB
# 143    RpoA(298)-RpoA(304)       1                    0            1  0  RpoA
# 144   RpoB(844)-RpoB(1262)       1                    0            1  0  RpoB
# 145    RpoB(639)-RpoB(431)       1                    0            1  0  RpoB
# 146    RpoB(639)-RpoB(914)       1                    0            1  0  RpoB
# 147    RpoB(639)-RpoC(334)       1                    0            1  0  RpoB
# 148     RpoB(639)-RpoC(40)       1                    0            1  0  RpoB
# 149    RpoB(639)-RpoC(992)       1                    0            1  0  RpoB
# 150   RpoB(719)-RpoB(1028)       1                    0            1  0  RpoB
# 151   RpoB(719)-RpoB(1032)       1                    0            1  0  RpoB
# 152    RpoB(719)-RpoB(163)       1                    0            1  0  RpoB
# 153    RpoB(719)-RpoC(334)       3                    0            1  0  RpoB
# 154    RpoB(914)-RpoC(395)       1                    0            1  0  RpoB
# 155    RpoB(844)-RpoB(639)       1                    0            1  0  RpoB
# 156    RpoB(844)-RpoB(890)       2                    0            1  0  RpoB
# 157    RpoB(844)-RpoB(900)       3                    0            1  0  RpoB
# 158    RpoB(844)-RpoB(909)       1                    0            1  0  RpoB
# 159    RpoB(844)-RpoB(914)       4                    0            1  0  RpoB
# 160     RpoB(844)-RpoC(40)       1                    0            1  0  RpoB
# 161     RpoB(844)-RpoC(50)       1                    0            1  0  RpoB
# 162     RpoB(844)-RpoC(66)       1                    1            1  0  RpoB
# 163    RpoB(844)-UvrD(501)       1                    0            1  0  RpoB
#
#      res1 prot2  res2
# 0      74  RpoC    79
# 1     623  UvrD   486
# 2     789  RpoC   334
# 3     161  RpoC   781
# 4     789  RpoC  1132
# 5     789  RpoB   163
# 6     789  RpoB  1073
# 7      87  RpoC    50
# 8    1132  RpoC   996
# 9     260  RpoB   279
# 10   1340  RpoC    40
# 11   1340  RpoC  1348
# 12   1340  RpoC   219
# 13   1340  RpoC   334
# 14   1340  RpoC   345
# 15   1297  RpoC    79
# 16   1348  RpoB   914
# 17   1348  RpoB    99
# 18   1348  RpoC   219
# 19   1348  RpoC   334
# 20   1348  RpoC   345
# 21   1348  RpoC     9
# 22    321  RpoB   639
# 23    321  RpoC  1340
# 24    321  RpoC  1348
# 25   1151  RpoC  1132
# 26    914  RpoC    50
# 27    914  RpoC    79
# 28    988  RpoB   279
# 29   1072  RpoB   265
# ..    ...   ...   ...
# 134   890  RpoB   909
# 135   900  RpoC     6
# 136   900  RpoC    79
# 137   900  RpoC     9
# 138   900  RpoC    96
# 139   900  UvrD   501
# 140   909  RpoC    40
# 141   909  RpoC    50
# 142   914  RpoB    13
# 143   298  RpoA   304
# 144   844  RpoB  1262
# 145   639  RpoB   431
# 146   639  RpoB   914
# 147   639  RpoC   334
# 148   639  RpoC    40
# 149   639  RpoC   992
# 150   719  RpoB  1028
# 151   719  RpoB  1032
# 152   719  RpoB   163
# 153   719  RpoC   334
# 154   914  RpoC   395
# 155   844  RpoB   639
# 156   844  RpoB   890
# 157   844  RpoB   900
# 158   844  RpoB   909
# 159   844  RpoB   914
# 160   844  RpoC    40
# 161   844  RpoC    50
# 162   844  RpoC    66
# 163   844  UvrD   501
#
# [164 rows x 15 columns]
